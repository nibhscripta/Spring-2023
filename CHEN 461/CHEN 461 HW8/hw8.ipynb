# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
import control

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sys = signal.lti([], [0, -1/0.1, -1/10], 1)

# %%
sys = control.zpk([0], [-1/10, -10], 10)
w, mag, phase = control.bode_plot(sys, dB=True)
# plt.figure()
# plt.semilogx(w, mag)
# plt.figure()
# plt.semilogx(w, phase) 
# plt.show()
# phase[0], phase[-1]
