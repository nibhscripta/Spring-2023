# %%
import control
from scipy import signal

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy.integrals import inverse_laplace_transform
from sympy.abc import t, s, tau, alpha, k


U = 1/s
real_pd = (1 + s) / (1 + alpha*s)
ideal_pd = (1 + s)

inverse_laplace_transform(real_pd * U, s, t)
# Out:
# (alpha*exp(t*(re(alpha) - I*im(alpha))/(re(alpha)**2 + im(alpha)**2)) - alpha + 1)*exp(-t*(re(alpha) - I*im(alpha))/(re(alpha)**2 + im(alpha)**2))*Heaviside(t)/alpha

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy.integrals import inverse_laplace_transform
from sympy.abc import t, s, tau, alpha, k
from sympy import symbols

# %%
tau_i, tau_d, tau_f = symbols("tau_i, tau_d, tau_f")
